# %% [markdown]
# <a href="https://colab.research.google.com/github/Emelsmsk/yapay-sinir-ag-/blob/main/yapay_sinirag%C4%B12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

def lineer_regresyon(x):
    a = 3
    b = 5
    y = a * x + b
    return y
"""
This function calculates the y value for a given x value using a linear regression model.
"""
x = np.linspace(0, 20, 20)
y = lineer_regresyon(x)
plt.plot(x, y)
plt.show()

# %%
y_23 = lineer_regresyon(23)
print(y_23)
# Out:
# 74

# %%
def f(x):
  return a * x + b

# %%
def lineer_regresyon_3d(x, y):
  return a * x + b * y
  print(lineer_regresyon_3d(3, 5))

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

def lineer_regresyon_3d(x, y):
  """
  Calculates the z value for a given x and y values using a linearregression model.
  """
  a = 3
  b = 5

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(0, 20, 20)
y = np.linspace(0, 20, 20)
X, Y = np.meshgrid(x, y)
Z = lineer_regresyon_3d(X, Y)

ax = fig.add_subplot(111, projection='3d')
x = np.linspace(0, 20, 20)
y = np.linspace(0, 20, 20)
X, Y = np.meshgrid(x, y)
def lineer_regresyon_3d(x, y):

 ax.plot_surface(X, Y, Z)
plt.show()

# %%
from binascii import b2a_base64
a1 = 3
b1 = 1
def f1(x):
  return a1 * x +b1

a2 = -2
b2 = 4
def f2(x):
  return a2 * x + b2
a3 = 3
b3 = -3
def f3(x):
  return a3 * x + b3
a4 = -4
b4 = 2
def f4(x):
  return a4 * x + b4
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 20, 20)
y1 = f1(x)
y2 = f2(x)
y3 = f3(x)
y4 = f4(x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)
plt.show()

# %%
x_son = 13
y1_son = f1(f2(f3(f4(x_son))))
print(y1_son)
# Out:
# 931

# %%
def fa1(x):
  return x + 1
def fa2(x):
  return x * 2
def fa3(x):
  return x - 3
def fb1(x):
  return x ** 2
def fc1(x):
  return x / 2
import numpy as np
x = np.linspace(-5, 5, 100)
c1 = fa3(fa2(fa1(x)))
c2 = fa3(fa2(fb1(x)))
c3 = fa3(fa2(fc1(x)))

# %%
def fa1(x):
  return a1 * x + b1
def fb1(x):
  return a1 * x + b1
def fc1(x):
  return a1 * x + b1
def fa2(x):
  return a2 * x + b2
def fb2(x):
  return a2 * x + b2
def fc2(x):
  return a2 * x + b2
def fd2(x):
  return a2 * x + b2
def fe2(x):
  return a2 * x + b2
def fa3(x):
  return a3 * x + b3
def fb3(x):
  return a3 * x + b3

# %%
w1 = 0.7
w2 = 0.3
w3 = 0.4
w4 = 0.6
w5 = 0.55
w6 = 0.45

b1 = 0.5
b2 = 0.5
b3 = 0.5
def l1f1(x1, x2):
  return x1 * w1 + x2 * w3 + b1
def l1f2(x1, x2):
  return x1 *w2 + x2 * w4 + b2
def of1(x1, x2):
  return x1 * w5 + x2 * w6 + b3
i1 =0.5
i2 = 0.3
mustafa_hoca = l1f1(i1, i2)
ali_hoca = l1f2(i1, i2)
final_deger = of1(mustafa_hoca, ali_hoca)
print(final_deger)
# Out:
# 1.407

# %%
import numpy as np
def sigmoid(x):
  return 1 / (1 + np.exp(-x))
  print(sigmoid(-14))

# %%
# !pip install numpy
import numpy as np
def sigmoid(x):
  return 1 / (1 + np.exp(-x))
w1 = 0.7
w2 = 0.3
w3 = 0.4
w4 = 0.6
w5 = 0.55
w6 = 0.45

def l1f1(x1, x2):
 l1_sonuc = x1 * w1 + x2 * w3
 return sigmoid(l1_sonuc)

def l1f2(x1, x2):
  l1_sonuc = x1 * w2 + x2 * w4
  return sigmoid(l1_sonuc)
def of1(x1, x2):
 of_sonuc = x1 * w5 + x2 * w6
 return sigmoid(of_sonuc)
i1 = 0.5
i2 = 0.3
mustafa_hoca = l1f1(i1, i2)
ali_hoca = l1f2(i1, i2)
final_deger = of1(mustafa_hoca, ali_hoca)
print(round(final_deger, 3))
# Out:
# ...
# 0.646

# %%
# sisteme yeni bir gizli katman(hidden layer)eklendi
matrix_i = np.array([[0.5, 0.3]])
matrix_l1w = np.array([[0.7, 0.3, 0.5],
                       [0.4, 0.6, 0.5]])
matrix_l2w = np.array([[0.7, 0.3, 0.7],
                       [0.4, 0.6, 0.5]])
matrix_ow = np.array([[0.55],
                      [0.45],
                      [0.5]])
matrix_i, matrix_l1w, matrix_l2w, matrix_ow
# Out:
# (array([[0.5, 0.3]]),
#  array([[0.7, 0.3, 0.5],
#         [0.4, 0.6, 0.5]]),
#  array([[0.7, 0.3, 0.7],
#         [0.4, 0.6, 0.5]]),
#  array([[0.55],
#         [0.45],
#         [0.5 ]]))

# %%
o1 = np.dot(matrix_i, matrix_l1w)
so1 = sigmoid(o1)
o2 = np.dot(so1, matrix_l2w.T)
so2 = sigmoid(o2)
o = np.dot(so2, matrix_l2w)
so3 = sigmoid(o)
round(so3[0][0], 3)
# Out:
# 0.69

# %%
#ilk hali
matrix_i = np.array([[0.5, 0.3]])
matrix_l1w = np.array([[0.7, 0.3],
                       [0.4, 0.6]])
matrix_ow = np.array([[0.55],
                      [0.45]])
matrix_i, matrix_l1w, matrix_ow
# Out:
# (array([[0.5, 0.3]]),
#  array([[0.7, 0.3],
#         [0.4, 0.6]]),
#  array([[0.55],
#         [0.45]]))

# %%
o1 = np.dot(matrix_i, matrix_l1w)
print(o1)
so1 = sigmoid(o1)
o = np.dot(so1, matrix_ow)
so = sigmoid(o)
round(so[0][0], 3)
# Out:
# [[0.47 0.33]]
# 0.646

# %%
''' w1 = 0.7010
w2 = 0.3009
w3 = 0.4011
w4 = 0.6005
w5 = 0.551
w6 = 0.4595 '''
import numpy as np

def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def l1f1(x1, x2):
  y = x1 * w2 + x2 * w3
  return y

def l2f2(x1, x2):
  y = x1 * w2 + x2 * w4
  return y

def l3f1(x1, x2):
  y = x1 * w5 + x2 * w6
  return y


''' def l1f1(x):
def l1f2(x):'''
girdi1 = 0.5
girdi2 = 0.3

ikinciKatmanCikti1 = l1f1(girdi1, girdi2)
ikinciKatmanCikti2 = l2f2(girdi1, girdi2)

print("ikinci katman çıktı:", ikinciKatmanCikti1)
print("ikinci katman çıktı:", ikinciKatmanCikti2)

o1 = sigmoid(l3f1(sigmoid(ikinciKatmanCikti1), sigmoid(ikinciKatmanCikti2)))
# l3f1(sigmoid(ikinciKatmanCikti1), sigmoid(ikinciKatmanCikti2))
print(round(o1, 3))
# Out:
# ikinci katman çıktı: 0.6530155760027647
# ikinci katman çıktı: 0.6945380554751239
# 0.961

# %%
def loss_or_cost(y_predicted, y_expected):
  fark = y_predicted - y_expected
  karesi = fark ** 2
  return round(karesi, 3)

loss_or_cost(o1, 1)
# Out:
# 0.129

# %%
# sigmoid(x) = 1 / 1 + e ^ -x
#tsigmoid =
def d_sigmoid(x):
  return x * (1 - x)

# %%
# x = y_p - y_e
#f(x) = x^2
# tf = 2x
dC_o1 = 2 * (o1 - 1)
dC_o1
# Out:
# -0.7178839599636253

# %%
#0.647 * (1- 0.647)
do1_so = d_sigmoid(o1)
do1_so
# Out:
# 0.23010263498854866

# %%
do1_dw5 = round(sigmoid(ikinciKatmanCikti1), 3)
do1_dw6 = round(sigmoid(ikinciKatmanCikti2), 3)

do1_dw5, do1_dw6
# Out:
# (0.567, 0.582)

# %%
dC_dw5 = round(dC_o1 * do1_so * do1_dw5, 3)
dC_dw6 = round(dC_o1 * do1_so * do1_dw6, 3)
''' w5 = w5 - dC_dw5
w6 = w6 - dC_dw6 '''
dC_dw5, dC_dw6, w5, w6
# Out:
# (-0.094, -0.096, 0.551, 0.4595)

# %%
do1_h1 = w5
do1_h2 = w6
do1_h1, do1_h2
# Out:
# (0.551, 0.4595)

# %%
def d_sigmoid(x):
  return x * (1 - x)
dh1_so1 = d_sigmoid(ikinciKatmanCikti1)

dC_dw1 = round(dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi1, 3)
dC_dw2 = round(dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi2, 3)

dh2_so2 = d_sigmoid(ikinciKatmanCikti2)

dC_dw3 = round(dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi1, 3)
dC_dw4 = round(dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi2, 3)

dC_dw1, dC_dw2, dC_dw3, dC_dw4
# Out:
# (-0.009, -0.005, -0.008, -0.005)

# %%
# w1 = w1 - dC_dw1
w1 -= dC_dw1
w2 -= dC_dw2
w3 -= dC_dw3
w4 -= dC_dw4
w5 -= dC_dw5
w6 -= dC_dw6
w1, w2, w3, w4, w5, w6
# Out:
# (0.71, 0.3059, 0.4091, 0.6055, 0.645, 0.5555)

# %% [markdown]
# Döngü ile yapma

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))
def d_sigmoid(x):
  return x * (1 - x)
def loss_or_cost(y_p, y_e):
  return (y_p - y_e) ** 2
def l2f1(x1, x2):
  return w1 * x1 + w2 * x2
def l2f2(x1, x2):
  return w3 * x1 + w4 * x2
def l3f1(h1, h2):
  return w5 * h1 + w6 * h2

w1 = 0.7010
w2 = 0.3009
w3 = 0.4011
w4 = 0.6005
w5 = 0.551
w6 = 0.4595

girdi1 = 0.5
girdi2 = 0.3

for i in range(100000):
  ikinciKatmanCikti1 = l2f1(girdi1, girdi2)
  ikinciKatmanCikti2 = l2f2(girdi1, girdi2)

o1 = sigmoid(l3f1(sigmoid(ikinciKatmanCikti1), sigmoid(ikinciKatmanCikti2)))
# x = y_p - y_e
#f(x) = x^2
# tf = 2x
dC_o1 = 2 * (o1 - 1)

#0.647 ^ (1- 0.647)
do1_so = d_sigmoid(o1)

do1_dw5 = sigmoid(ikinciKatmanCikti1)
do1_dw6 = sigmoid(ikinciKatmanCikti2)

dC_dw5 = dC_o1 * do1_so * do1_dw5
dC_dw6 = dC_o1 * do1_so * do1_dw6
''' w5 = w5 - dC_dw5
w6 = w6 - dC_dw6 '''
do1_h1 = w5
do1_h2 = w6

dh1_so1 = d_sigmoid(ikinciKatmanCikti1)
dh2_so2 = d_sigmoid(ikinciKatmanCikti2)

dC_dw1 = dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi1
dC_dw2 = dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi2
dC_dw3 = dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi1
dC_dw4 = dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi2

w1 -= dC_dw1
w2 -= dC_dw2
w3 -= dC_dw3
w4 -= dC_dw4
w5 -= dC_dw5
w6 -= dC_dw6
if (i % 5000 == 0):
  print(i, ".Adım sonrası hata miktarı: ", loss_or_cost(o1, 1), "Yeni tahmin: ", o1)

# %%
w1, w2, w3, w4, w5, w6
# Out:
# (0.7119257781453324,
#  0.3074554668871995,
#  0.40981500744758254,
#  0.6057290044685495,
#  0.64889213972523,
#  0.5550752364730506)

# %%
w1 = 0.7010
w2 = 0.3009
w3 = 0.4011
w4 = 0.6005
w5 = 0.551
w6 = 0.4595

girdi1 = 0.5
girdi2 = 0.3

ogrenciler = [
  {    "vize": 0.6,
    "final": 0.5,
    "sonuc": 1
  },
  {
    "vize": 0.69,
    "final": 0.57,
    "sonuc": 1
  },
  {
    "vize": 0.86,
    "final": 0.95,
    "sonuc": 1
  },
  {
    "vize": 0.69,
    "final": 0.57,
    "sonuc": 1
  }
]

for i in range(100):
  for ogrenci in ogrenciler:
    girdi1 = ogrenci["vize"]
    girdi2 = ogrenci["final"]
    ikinciKatmanCikti1 = l2f1(girdi1, girdi2)
    ikinciKatmanCikti2 = l2f2(girdi1, girdi2)

    o1 = sigmoid(l3f1(sigmoid(ikinciKatmanCikti1), sigmoid(ikinciKatmanCikti2)))
    # x = y_p - y_e
    # f(x) = x^2
    # tf = 2x
    dC_o1 = 2 * (o1 - ogrenci["sonuc"])

    # 0.647 * (1 - 0.647)
    do1_so = d_sigmoid(o1)

    do1_dw5 = sigmoid(ikinciKatmanCikti1)
    do1_dw6 = sigmoid(ikinciKatmanCikti2)

    dC_dw5 = dC_o1 * do1_so * do1_dw5
    dC_dw6 = dC_o1 * do1_so * do1_dw6
    ''' w5 = w5 - dC_dw6 '''
    do1_h1 = w5
    do1_h2 = w6

    dh1_so1 = d_sigmoid(sigmoid(ikinciKatmanCikti1))
    dh2_so2 = d_sigmoid(sigmoid(ikinciKatmanCikti2))

    dC_dw1 = dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi1
    dC_dw2 = dC_o1 * do1_so * do1_h1 * dh1_so1 * girdi2
    dC_dw3 = dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi1
    dC_dw4 = dC_o1 * do1_so * do1_h2 * dh2_so2 * girdi2

    w1 -= dC_dw1
    w2 -= dC_dw2
    w3 -= dC_dw3
    w4 -= dC_dw4
    w5 -= dC_dw5
    w6 -= dC_dw6
  if (i % 5 == 0):
   print(i, ".Adım sonrası hata miktarı: ", loss_or_cost(o1, ogrenci["sonuc"]), "Yeni tahmin:", o1)
# Out:
# 0 .Adım sonrası hata miktarı:  0.07014918745778748 Yeni tahmin: 0.7351430811593032
# 5 .Adım sonrası hata miktarı:  0.013648141279405678 Yeni tahmin: 0.8831747404051432
# 10 .Adım sonrası hata miktarı:  0.006731380882558531 Yeni tahmin: 0.917955006962286
# 15 .Adım sonrası hata miktarı:  0.004323202702692279 Yeni tahmin: 0.9342489338284748
# 20 .Adım sonrası hata miktarı:  0.0031374889039048775 Yeni tahmin: 0.9439867077926598
# 25 .Adım sonrası hata miktarı:  0.0024421898816006774 Yeni tahmin: 0.9505814824018296
# 30 .Adım sonrası hata miktarı:  0.001989001421576625 Yeni tahmin: 0.9554017778204487
# 35 .Adım sonrası hata miktarı:  0.0016719126367118532 Yeni tahmin: 0.9591109716829581
# 40 .Adım sonrası hata miktarı:  0.0014384741975002752 Yeni tahmin: 0.9620727776194951
# 45 .Adım sonrası hata miktarı:  0.001259915918968941 Yeni tahmin: 0.9645047056785137
# 50 .Adım sonrası hata miktarı:  0.00111920169842481 Yeni tahmin: 0.9665455279756979
# ...
